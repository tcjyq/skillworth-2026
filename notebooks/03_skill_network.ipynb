# %% [markdown]
# # Skill Co-occurrence Network
#
# 本 Notebook 只调用现有 Analytics Module 构建共现网络、过滤低支持边并执行社区发现。

# %%
from pathlib import Path

from skillworth_analytics import AdvancedAnalyticsRepository, AnalyticsFilters

repository_root = Path.cwd()
analytics = AdvancedAnalyticsRepository(repository_root / 'data/warehouse/skillworth.duckdb')

# %%
network_report = analytics.build_skill_network(filters=AnalyticsFilters())
network_report.model_dump()
